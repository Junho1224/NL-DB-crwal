# %% [markdown]
# ## 네이버랜드 크롤링
#
# https://m.land.naver.com/search/result/양천구신월동

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import math
import re

# %%
#임의의 btm, lft, top, rgt값 계산

def calculate_bounding_box(lat, lon, zoom):
    # Earth's radius in meters
    R = 6378137
    # Approximate bounding box in meters for zoom level 14 (usually covers around 1km)
    bounding_box_half_side_length = 1000  # 1km / 2

    # Convert latitude and longitude from degrees to radians
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    
    # Offset calculations
    lat_offset = (bounding_box_half_side_length / R) * (180 / math.pi)
    lon_offset = (bounding_box_half_side_length / (R * math.cos(lat_rad))) * (180 / math.pi)
    
    # Calculate bounding box coordinates
    btm = lat - lat_offset
    lft = lon - lon_offset
    top = lat + lat_offset
    rgt = lon + lon_offset
    
    return btm, lft, top, rgt

# %%
keyword = "종로구 무악동"

# %%
url = "https://m.land.naver.com/search/result/{}".format(keyword)

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Referer': 'https://m.land.naver.com/'
}

res = requests.get(url, headers=headers)
res.raise_for_status()

soup = str(BeautifulSoup(res.text, 'lxml'))

# filter 값 추출
value = soup.split("filter: {")[1].split("}")[0].replace(" ","").replace("'","")

print(value)

lat = (float)(value.split("lat:")[1].split(",")[0])
lon = (float)(value.split("lon:")[1].split(",")[0])
z = (int)(value.split("z:")[1].split(",")[0])
cortarNo = value.split("cortarNo:")[1].split(",")[0]
rletTpCds = value.split("rletTpCds:")[1].split(",")[0]
tradTpCds = value.split("tradTpCds:")[1].split()[0]


#임의의 btm, lft, top, rgt값 계산
btm, lft, top, rgt = calculate_bounding_box(lat, lon, z)
print(f"btm: {btm}, lft: {lft}, top: {top}, rgt: {rgt}")


# clusterList URL
clusterList_URL = "https://m.land.naver.com/cluster/clusterList?view=atcl&cortarNo={}&rletTpCd={}&tradTpCd={}&z={}&lat={}&lon={}&btm={}&lft={}&top={}&rgt={}"\
    .format(cortarNo, rletTpCds, tradTpCds, z, lat, lon, btm, lft, top, rgt)
print(clusterList_URL)

# clusterList URL로 GET 요청
res2 = requests.get(clusterList_URL, headers=headers)
res2.raise_for_status()
# print(res2.text)

# 데이터 파싱
try:
    data = res2.json()
    # print(json.dumps(data, indent=2, ensure_ascii=False))
except json.JSONDecodeError as e:
    print("JSON 데이터를 파싱할 수 없습니다:", e)
    print("응답 내용:", res2.text)
    
values = data['data']['ARTICLE']
# print(values)

result_list = []
# 큰 원으로 구성되어 있는 전체 매물그룹(values)을 load 하여 한 그룹씩 세부 쿼리 진행
for v in values:
    lgeo = v['lgeo']
    count = v['count']
    z2 = v['z']
    lat2 = v['lat']
    lon2 = v['lon']

    len_pages = math.ceil(count / 20) + 1
    for idx in range(1, len_pages):

        # articleList_URL    
        articleList_URL = "https://m.land.naver.com/cluster/ajax/articleList?""itemId={}&mapKey=&lgeo={}&showR0=&" \
               "rletTpCd={}&tradTpCd={}&z={}&lat={}&""lon={}&totCnt={}&cortarNo={}&page={}"\
            .format(lgeo, lgeo, rletTpCds, tradTpCds, z2, lat2, lon2, count,cortarNo, idx)
        # print(articleList_URL)
        res3 = requests.get(articleList_URL, headers=headers)
        res3.raise_for_status()
                
        try:
            data2 = res3.json()
            articles = data2['body']
            for article in articles:
                result_list.append(article)
        except json.JSONDecodeError as e:
            print("JSON 데이터를 파싱할 수 없습니다:", e)
            print("응답 내용:", res3.text)


df = pd.DataFrame(result_list)

selected_columns = ["atclNo", "atclNm", "rletTpNm","tradTpNm", "flrInfo", "prc","rentPrc","hanPrc","spc1","spc2", "direction","atclCfmYmd" ,"lat", "lng", "atclFetrDesc", "tagList","bildNm","town"]
df["town"] = keyword
df = df[selected_columns].reset_index(drop=True)

print(len(df))

df.to_csv(f'./dataNop/{keyword}_crawling.csv', index=False, encoding='utf-8-sig')
print("CSV 파일로 저장되었습니다.")
# Out:
# lat:37.576008,
# lon:126.958098,
# z:14,
# cortarNo:1111018700,
# cortarNm:무악동,
# rletTpCds:*,
# tradTpCds:A1:B1:B2
#
# btm: 37.567024847158805, lft: 126.9467634359103, top: 37.5849911528412, rgt: 126.96943256408971
# https://m.land.naver.com/cluster/clusterList?view=atcl&cortarNo=1111018700&rletTpCd=*&tradTpCd=A1:B1:B2&z=14&lat=37.576008&lon=126.958098&btm=37.567024847158805&lft=126.9467634359103&top=37.5849911528412&rgt=126.96943256408971
# 141
# CSV 파일로 저장되었습니다.

# %% [markdown]
# ### 데이터 전처리

# %%
#csv 합치기
import os

folder_path = './dataNop'

# 폴더 내 모든 CSV 파일을 불러와 하나의 데이터 프레임으로 합치는 함수
def merge_csv_files(folder_path):
    # 폴더 내 모든 CSV 파일 리스트 가져오기
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    print(csv_files)

    # 빈 데이터 프레임 리스트 생성
    dataframes = []

    # 각 CSV 파일을 읽어서 데이터 프레임 리스트에 추가
    for file in csv_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        dataframes.append(df)

    # 모든 데이터 프레임을 하나로 합치기
    merged_df = pd.concat(dataframes, ignore_index=True)

    return merged_df

# 함수 호출 및 결과 저장
merged_df = merge_csv_files(folder_path)

# 결과 출력
merged_df.head()
# Out:
# ['강남구개포1동_crawling.csv', '강남구개포2동_crawling.csv', '강남구개포4동_crawling.csv', '강남구논현1동_crawling.csv', '강남구논현2동_crawling.csv', '강남구대치1동_crawling.csv', '강남구대치2동_crawling.csv', '강남구대치4동_crawling.csv', '강남구도곡1동_crawling.csv', '강남구도곡2동_crawling.csv', '강남구삼성1동_crawling.csv', '강남구삼성2동_crawling.csv', '강남구세곡동_crawling.csv', '강남구수서동_crawling.csv', '강남구신사동_crawling.csv', '강남구압구정동_crawling.csv', '강남구역삼1동_crawling.csv', '강남구역삼2동_crawling.csv', '강남구일원1동_crawling.csv', '강남구일원본동_crawling.csv', '강남구청담동_crawling.csv']
#        atclNo        atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0  2430493738  디에이치퍼스티어아이파크      아파트       전세    8/26  175000        0
# 1  2430483040  디에이치퍼스티어아이파크      아파트       월세   17/35   50000      440
# 2  2430483852  디에이치퍼스티어아이파크      아파트       전세   22/33  290000        0
# 3  2430476863  디에이치퍼스티어아이파크      아파트       전세   16/18   68000        0
# 4  2430461819  디에이치퍼스티어아이파크      아파트       월세   30/33  100000      600
#
#       hanPrc spc1    spc2 direction atclCfmYmd        lat         lng  \
# 0  17억 5,000  144  112.85       남동향  24.06.21.  37.482462  127.056707
# 1         5억  125   96.82       남서향  24.06.21.  37.479760  127.058636
# 2        29억  201  156.96       남동향  24.06.21.  37.481182  127.057478
# 3   6억 8,000   50   34.99       남서향  24.06.21.  37.478622  127.056892
# 4        10억  201  156.96       남동향  24.06.21.  37.481182  127.057478
#
#                              atclFetrDesc                            tagList  \
# 0  44 1획지 주인직접 초역세권 식세 초중품아 채광.전망굿 고급커뮤니티   ['2년이내', '대단지', '대형평수', '방네개이상']
# 1   38. 커뮤니티 최상. 조중석식.풀에,이태리산 아트월, 식세기 옵션  ['2년이내', '융자금없는', '대단지', '방네개이상']
# 2  61.대형 평형 다량보유.중앙공원뷰.이태리아트월,붙박이장,오븐,식세기   ['2년이내', '융자금없는', '대단지', '대형평수']
# 3             15 주인의뢰,귀한소형, 탁트인뷰, 럭셔리커뮤니티     ['2년이내', '대단지', '소형평수', '방한개']
# 4                   61 빠른입주,보증금10억에서 부터가능   ['2년이내', '융자금없는', '대단지', '대형평수']
#
#   bildNm     town
# 0   118동  강남구개포1동
# 1   174동  강남구개포1동
# 2   103동  강남구개포1동
# 3   140동  강남구개포1동
# 4   103동  강남구개포1동

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34270 entries, 0 to 34269
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   atclNo        34270 non-null  int64
#  1   atclNm        34270 non-null  object
#  2   rletTpNm      34270 non-null  object
#  3   tradTpNm      34270 non-null  object
#  4   flrInfo       34270 non-null  object
#  5   prc           34270 non-null  int64
#  6   rentPrc       34270 non-null  int64
#  7   hanPrc        34264 non-null  object
#  8   spc1          34270 non-null  object
#  9   spc2          34270 non-null  float64
#  10  direction     32542 non-null  object
#  11  atclCfmYmd    34270 non-null  object
#  12  lat           34270 non-null  float64
#  13  lng           34270 non-null  float64
#  14  atclFetrDesc  32199 non-null  object
#  15  tagList       34270 non-null  object
#  16  bildNm        9106 non-null   object
#  17  town          34270 non-null  object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 4.7+ MB

# %%
#중복 제거

merged_df.drop_duplicates()
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34270 entries, 0 to 34269
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   atclNo        34270 non-null  int64
#  1   atclNm        34270 non-null  object
#  2   rletTpNm      34270 non-null  object
#  3   tradTpNm      34270 non-null  object
#  4   flrInfo       34270 non-null  object
#  5   prc           34270 non-null  int64
#  6   rentPrc       34270 non-null  int64
#  7   hanPrc        34264 non-null  object
#  8   spc1          34270 non-null  object
#  9   spc2          34270 non-null  float64
#  10  direction     32542 non-null  object
#  11  atclCfmYmd    34270 non-null  object
#  12  lat           34270 non-null  float64
#  13  lng           34270 non-null  float64
#  14  atclFetrDesc  32199 non-null  object
#  15  tagList       34270 non-null  object
#  16  bildNm        9106 non-null   object
#  17  town          34270 non-null  object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 4.7+ MB

# %% [markdown]
# #### 1. 날짜 형식 변경

# %%
from datetime import datetime

# %%
def convert_to_mysql_format(date_str):
    date_obj = datetime.strptime(date_str, "%y.%m.%d.")
    return date_obj.strftime("%Y-%m-%d")

# 'atclCfmYmd' 열의 값을 MySQL 형식으로 변환
df['atclCfmYmd_mysql'] = df['atclCfmYmd'].apply(convert_to_mysql_format)
print("MySQL 형식으로 변환된 데이터 프레임:\n", df)

# %%
def convert_to_mongodb_format(date_str):
    date_obj = datetime.strptime(date_str, "%y.%m.%d.")
    return date_obj.isoformat()

# 'atclCfmYmd' 열의 값을 MongoDB 형식으로 변환
merged_df['atclCfmYmd'] = merged_df['atclCfmYmd'].apply(convert_to_mongodb_format)
merged_df.head()
# Out:
#        atclNo        atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0  2430493738  디에이치퍼스티어아이파크      아파트       전세    8/26  175000        0
# 1  2430483040  디에이치퍼스티어아이파크      아파트       월세   17/35   50000      440
# 2  2430483852  디에이치퍼스티어아이파크      아파트       전세   22/33  290000        0
# 3  2430476863  디에이치퍼스티어아이파크      아파트       전세   16/18   68000        0
# 4  2430461819  디에이치퍼스티어아이파크      아파트       월세   30/33  100000      600
#
#       hanPrc spc1    spc2 direction           atclCfmYmd        lat  \
# 0  17억 5,000  144  112.85       남동향  2024-06-21T00:00:00  37.482462
# 1         5억  125   96.82       남서향  2024-06-21T00:00:00  37.479760
# 2        29억  201  156.96       남동향  2024-06-21T00:00:00  37.481182
# 3   6억 8,000   50   34.99       남서향  2024-06-21T00:00:00  37.478622
# 4        10억  201  156.96       남동향  2024-06-21T00:00:00  37.481182
#
#           lng                            atclFetrDesc  \
# 0  127.056707  44 1획지 주인직접 초역세권 식세 초중품아 채광.전망굿 고급커뮤니티
# 1  127.058636   38. 커뮤니티 최상. 조중석식.풀에,이태리산 아트월, 식세기 옵션
# 2  127.057478  61.대형 평형 다량보유.중앙공원뷰.이태리아트월,붙박이장,오븐,식세기
# 3  127.056892             15 주인의뢰,귀한소형, 탁트인뷰, 럭셔리커뮤니티
# 4  127.057478                   61 빠른입주,보증금10억에서 부터가능
#
#                              tagList bildNm     town
# 0   ['2년이내', '대단지', '대형평수', '방네개이상']   118동  강남구개포1동
# 1  ['2년이내', '융자금없는', '대단지', '방네개이상']   174동  강남구개포1동
# 2   ['2년이내', '융자금없는', '대단지', '대형평수']   103동  강남구개포1동
# 3     ['2년이내', '대단지', '소형평수', '방한개']   140동  강남구개포1동
# 4   ['2년이내', '융자금없는', '대단지', '대형평수']   103동  강남구개포1동

# %% [markdown]
# #### 2. 아파트, 오피스텔 나누기
# 경도, 위도를 활용해 도로명주소, 지번주소 추가

# %%
apartment_df = merged_df[merged_df['rletTpNm'] == '아파트']
officetel_df = merged_df[merged_df['rletTpNm'] == '오피스텔']

# %%
officetel_df.to_csv('./dataNop/officetel.csv', index=False, encoding='utf-8-sig')

# %%
officetel_df
# Out:
#            atclNo     atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 458    2429962181        렉스힐     오피스텔       매매     2/7   41000        0
# 1175   2429962181        렉스힐     오피스텔       매매     2/7   41000        0
# 2466   2430511404  강남역서희스타힐스     오피스텔       매매    9/12   27000        0
# 2468   2430373834   강남웅진베어스빌     오피스텔       월세    6/16   10000      110
# 2470   2430327129   강남웅진베어스빌     오피스텔       전세    6/16   32000        0
# ...           ...        ...      ...      ...     ...     ...      ...
# 34187  2427092490        리버뷰     오피스텔       월세   14/15    1000       80
# 34203  2429060192     더오키드청담     오피스텔       월세   13/17   20000      700
# 34214  2428816002     더오키드청담     오피스텔       매매    6/17  245000        0
# 34244  2426348898        리버뷰     오피스텔       월세   14/15    1000      100
# 34261  2428555677     더오키드청담     오피스텔       월세    9/17   10000      550
#
#           hanPrc spc1   spc2 direction           atclCfmYmd        lat  \
# 458     4억 1,000   45  29.25       남동향  2024-06-18T00:00:00  37.483014
# 1175    4억 1,000   45  29.25       남동향  2024-06-18T00:00:00  37.483014
# 2466    2억 7,000   65  29.88        동향  2024-06-21T00:00:00  37.491413
# 2468          1억   48  26.26        북향  2024-06-20T00:00:00  37.490213
# 2470    3억 2,000   48  26.26        북향  2024-06-20T00:00:00  37.490213
# ...          ...  ...    ...       ...                  ...        ...
# 34187      1,000   52  30.36       남서향  2024-06-03T00:00:00  37.522278
# 34203         2억   94  69.17        동향  2024-06-13T00:00:00  37.522677
# 34214  24억 5,000   94  69.17       북동향  2024-06-12T00:00:00  37.522677
# 34244      1,000   68  39.16        서향  2024-05-29T00:00:00  37.522278
# 34261         1억   76  56.05        동향  2024-06-11T00:00:00  37.522677
#
#               lng                           atclFetrDesc  \
# 458    127.062559                 임대안고 매매 구룹과외등 공부방으로 최적
# 1175   127.062559                 임대안고 매매 구룹과외등 공부방으로 최적
# 2466   127.032589                                    NaN
# 2468   127.032788                     전입대출,보증보험가능,층고높은복층
# 2470   127.032788                     전입대출,보증보험가능,층고높은복층
# ...           ...                                    ...
# 34187  127.055325                초역세권 청담공원전망 개별냉난방 업무시설
# 34203  127.055081  소유주직접의뢰  한강뷰 공원뷰 청담역초역세권 건조기 스타일러 식세기
# 34214  127.055081               청담역 영동대교 남단 신축 하이엔드 오피스텔
# 34244  127.055325                           대로변 업무용 오피스텔
# 34261  127.055081                청담동 투룸 하이엔드 오피스텔 더오키드청담
#
#                                   tagList bildNm     town road_address address
# 458       ['15년이내', '필로티', '소형평수', '방한개']     1동  강남구개포1동         None    None
# 1175      ['15년이내', '필로티', '소형평수', '방한개']     1동  강남구개포2동         None    None
# 2466      ['15년이내', '화장실한개', '방한개', '고층']     1동  강남구개포4동         None    None
# 2468              ['10년이내', '복층', '소형평수']     1동  강남구개포4동         None    None
# 2470              ['10년이내', '복층', '소형평수']     1동  강남구개포4동         None    None
# ...                                   ...    ...      ...          ...     ...
# 34187  ['25년이상', '융자금없는', '역세권', '화장실한개']     1동   강남구청담동         None    None
# 34203              ['2년이내', '역세권', '방한개']     1동   강남구청담동         None    None
# 34214              ['2년이내', '역세권', '방두개']     1동   강남구청담동         None    None
# 34244    ['25년이상', '융자금없는', '역세권', '방한개']     1동   강남구청담동         None    None
# 34261              ['2년이내', '역세권', '방한개']     1동   강남구청담동         None    None
#
# [1564 rows x 20 columns]

# %%
apartment_df['road_address'] = None
apartment_df['address'] = None
# Out:
# C:\Users\bitcamp\AppData\Local\Temp\ipykernel_25696\2191241167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apartment_df['road_address'] = None
# C:\Users\bitcamp\AppData\Local\Temp\ipykernel_25696\2191241167.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apartment_df['address'] = None

# %%
officetel_df['road_address'] = None
officetel_df['address'] = None
# Out:
# C:\Users\bitcamp\AppData\Local\Temp\ipykernel_25696\2192126235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   officetel_df['road_address'] = None
# C:\Users\bitcamp\AppData\Local\Temp\ipykernel_25696\2192126235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   officetel_df['address'] = None

# %%
officetel_df.head()
# Out:
#           atclNo     atclNm rletTpNm tradTpNm flrInfo    prc  rentPrc  \
# 458   2429962181        렉스힐     오피스텔       매매     2/7  41000        0
# 1175  2429962181        렉스힐     오피스텔       매매     2/7  41000        0
# 2466  2430511404  강남역서희스타힐스     오피스텔       매매    9/12  27000        0
# 2468  2430373834   강남웅진베어스빌     오피스텔       월세    6/16  10000      110
# 2470  2430327129   강남웅진베어스빌     오피스텔       전세    6/16  32000        0
#
#         hanPrc spc1   spc2 direction           atclCfmYmd        lat  \
# 458   4억 1,000   45  29.25       남동향  2024-06-18T00:00:00  37.483014
# 1175  4억 1,000   45  29.25       남동향  2024-06-18T00:00:00  37.483014
# 2466  2억 7,000   65  29.88        동향  2024-06-21T00:00:00  37.491413
# 2468        1억   48  26.26        북향  2024-06-20T00:00:00  37.490213
# 2470  3억 2,000   48  26.26        북향  2024-06-20T00:00:00  37.490213
#
#              lng            atclFetrDesc                          tagList  \
# 458   127.062559  임대안고 매매 구룹과외등 공부방으로 최적  ['15년이내', '필로티', '소형평수', '방한개']
# 1175  127.062559  임대안고 매매 구룹과외등 공부방으로 최적  ['15년이내', '필로티', '소형평수', '방한개']
# 2466  127.032589                     NaN  ['15년이내', '화장실한개', '방한개', '고층']
# 2468  127.032788      전입대출,보증보험가능,층고높은복층          ['10년이내', '복층', '소형평수']
# 2470  127.032788      전입대출,보증보험가능,층고높은복층          ['10년이내', '복층', '소형평수']
#
#      bildNm     town road_address address
# 458      1동  강남구개포1동         None    None
# 1175     1동  강남구개포2동         None    None
# 2466     1동  강남구개포4동         None    None
# 2468     1동  강남구개포4동         None    None
# 2470     1동  강남구개포4동         None    None

# %%
import requests
import pandas as pd
import json
import xml.etree.ElementTree as ET
from dotenv import load_dotenv
import os

# %%
# Kakao API를 사용하여 좌표를 주소로 변환하는 함수
def reverse_geocode(lat, lon):
    url = "https://dapi.kakao.com/v2/local/geo/coord2address.json"
    headers = {"Authorization": f"KakaoAK 2c032c6e9e2fe1461d1df5cd1ebc6fbe"}
    params = {"x": lon, "y": lat, "input_coord": "WGS84"}
    
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 200:
        result = response.json()
        if result['meta']['total_count'] > 0:
            address = result['documents'][0]
            road_address = address.get('road_address')
            if road_address:
                return road_address['address_name'], address['address']['address_name']
            else:
                return None, address['address']['address_name']
        else:
            return None, "No address found"
    else:
        return None, f"Error: {response.status_code}"

# %%
#주소기반산업서비스 API
def get_road_address_from_juso(address):
    api_url = f"http://business.juso.go.kr/addrlink/addrLinkApi.do?currentPage=1&countPerPage=10&keyword={address}&confmKey=devU01TX0FVVEgyMDI0MDUyOTIwMTYwODExNDgwNTM="
    response = requests.get(api_url)
    
    if response.status_code == 200:
        tree = ET.ElementTree(ET.fromstring(response.content))
        root = tree.getroot()
        road_addr = root.find(".//roadAddrPart1")
        if road_addr is not None:
            return road_addr.text
        else:
            return None
    else:
        return None

# %%
# 각 좌표에 대해 API 호출 및 주소 추가
for idx, row in apartment_df.iterrows():
    lat = row['lat']
    lon = row['lng']
    road_addr, addr = reverse_geocode(lat, lon)
    if road_addr is None and addr is not None:
        road_addr = get_road_address_from_juso(addr)
    apartment_df.at[idx, 'road_address'] = road_addr
    apartment_df.at[idx, 'address'] = addr

# 결과를 새로운 CSV 파일로 저장
apartment_df.to_csv('Apartment_with_address.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connectionpool.py:497, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     496 try:
# --> 497     conn.request(
#     498         method,
#     499         url,
#     500         body=body,
#     501         headers=headers,
#     502         chunked=chunked,
#     503         preload_content=preload_content,
#     504         decode_content=decode_content,
#     505         enforce_content_length=enforce_content_length,
#     506     )
#     508 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     509 # legitimately able to close the connection after sending a valid response.
#     510 # With this behaviour, the received response is still readable.
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#
# File c:\Users\bitcamp\anaconda3\Lib\http\client.py:1289, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1288     raise CannotSendHeader()
# -> 1289 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\bitcamp\anaconda3\Lib\http\client.py:1048, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1047 del self._buffer[:]
# -> 1048 self.send(msg)
#    1050 if message_body is not None:
#    1051
#    1052     # create a consistent interface to message_body
#
# File c:\Users\bitcamp\anaconda3\Lib\http\client.py:986, in HTTPConnection.send(self, data)
#     985 if self.auto_open:
# --> 986     self.connect()
#     987 else:
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connection.py:212, in HTTPConnection._new_conn(self)
#     211 except SocketTimeout as e:
# --> 212     raise ConnectTimeoutError(
#     213         self,
#     214         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     215     ) from e
#     217 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x000001C529DBBC10>, 'Connection to business.juso.go.kr timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='business.juso.go.kr', port=80): Max retries exceeded with url: /addrlink/addrLinkApi.do?currentPage=1&countPerPage=10&keyword=Error:%20401&confmKey=devU01TX0FVVEgyMDI0MDUyOTIwMTYwODExNDgwNTM= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001C529DBBC10>, 'Connection to business.juso.go.kr timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[60], line 7
#       5 road_addr, addr = reverse_geocode(lat, lon)
#       6 if road_addr is None and addr is not None:
# ----> 7     road_addr = get_road_address_from_juso(addr)
#       8 apartment_df.at[idx, 'road_address'] = road_addr
#       9 apartment_df.at[idx, 'address'] = addr
#
# Cell In[59], line 4, in get_road_address_from_juso(address)
#       2 def get_road_address_from_juso(address):
#       3     api_url = f"http://business.juso.go.kr/addrlink/addrLinkApi.do?currentPage=1&countPerPage=10&keyword={address}&confmKey=devU01TX0FVVEgyMDI0MDUyOTIwMTYwODExNDgwNTM="
# ----> 4     response = requests.get(api_url)
#       6     if response.status_code == 200:
#       7         tree = ET.ElementTree(ET.fromstring(response.content))
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\bitcamp\anaconda3\Lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPConnectionPool(host='business.juso.go.kr', port=80): Max retries exceeded with url: /addrlink/addrLinkApi.do?currentPage=1&countPerPage=10&keyword=Error:%20401&confmKey=devU01TX0FVVEgyMDI0MDUyOTIwMTYwODExNDgwNTM= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001C529DBBC10>, 'Connection to business.juso.go.kr timed out. (connect timeout=None)'))

# %%
apartment_df
# Out:
#            atclNo        atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0      2430493738  디에이치퍼스티어아이파크      아파트       전세    8/26  175000        0
# 1      2430483040  디에이치퍼스티어아이파크      아파트       월세   17/35   50000      440
# 2      2430483852  디에이치퍼스티어아이파크      아파트       전세   22/33  290000        0
# 3      2430476863  디에이치퍼스티어아이파크      아파트       전세   16/18   68000        0
# 4      2430461819  디에이치퍼스티어아이파크      아파트       월세   30/33  100000      600
# ...           ...           ...      ...      ...     ...     ...      ...
# 34253  2428643976        삼성청담공원      아파트       월세   13/15   20000      400
# 34260  2428619763        삼성청담공원      아파트       월세   13/15   10000      450
# 34262  2428669451       청담어퍼하우스      아파트       매매     4/7  800000        0
# 34264  2427714773     청담대우유로카운티      아파트       매매    고/17  320000        0
# 34267  2429725840       청담린든그로브      아파트       매매     저/7  300000        0
#
#           hanPrc spc1    spc2 direction           atclCfmYmd        lat  \
# 0      17억 5,000  144  112.85       남동향  2024-06-21T00:00:00  37.482462
# 1             5억  125   96.82       남서향  2024-06-21T00:00:00  37.479760
# 2            29억  201  156.96       남동향  2024-06-21T00:00:00  37.481182
# 3       6억 8,000   50   34.99       남서향  2024-06-21T00:00:00  37.478622
# 4            10억  201  156.96       남동향  2024-06-21T00:00:00  37.481182
# ...          ...  ...     ...       ...                  ...        ...
# 34253         2억  132  107.22       남서향  2024-06-11T00:00:00  37.522400
# 34260         1억  132  107.22       남서향  2024-06-11T00:00:00  37.522400
# 34262        80억  225  197.73        남향  2024-06-11T00:00:00  37.520901
# 34264        32억  141  120.89       남동향  2024-06-06T00:00:00  37.523330
# 34267        30억  114   84.99       남동향  2024-06-17T00:00:00  37.522550
#
#               lng                            atclFetrDesc  \
# 0      127.056707  44 1획지 주인직접 초역세권 식세 초중품아 채광.전망굿 고급커뮤니티
# 1      127.058636   38. 커뮤니티 최상. 조중석식.풀에,이태리산 아트월, 식세기 옵션
# 2      127.057478  61.대형 평형 다량보유.중앙공원뷰.이태리아트월,붙박이장,오븐,식세기
# 3      127.056892             15 주인의뢰,귀한소형, 탁트인뷰, 럭셔리커뮤니티
# 4      127.057478                   61 빠른입주,보증금10억에서 부터가능
# ...           ...                                     ...
# 34253  127.050597     올수리 깨끗 ,공원인접 ,보증금조정가능, 청담역세권,빠른입주가능
# 34260  127.050597            채광좋은 남향 내부깨끗 보증금낮은 월세 청담공원인근
# 34262  127.050220               청담동 신축급 고급빌라 어퍼하우스 즉시입주가능
# 34264  127.049406                   전체수리 스카이뷰시원한 조망권 협의입주
# 34267  127.053822        공원인접 신축급 보안좋고 구조좋은 청담동 고급아파트  매물
#
#                                    tagList bildNm     town road_address  \
# 0         ['2년이내', '대단지', '대형평수', '방네개이상']   118동  강남구개포1동         None
# 1        ['2년이내', '융자금없는', '대단지', '방네개이상']   174동  강남구개포1동         None
# 2         ['2년이내', '융자금없는', '대단지', '대형평수']   103동  강남구개포1동         None
# 3           ['2년이내', '대단지', '소형평수', '방한개']   140동  강남구개포1동         None
# 4         ['2년이내', '융자금없는', '대단지', '대형평수']   103동  강남구개포1동         None
# ...                                    ...    ...      ...          ...
# 34253      ['25년이내', '올수리', '역세권', '대형평수']   105동   강남구청담동         None
# 34260    ['25년이내', '역세권', '대형평수', '방네개이상']   105동   강남구청담동         None
# 34262             ['10년이내', '역세권', '대형평수']     1동   강남구청담동         None
# 34264  ['25년이내', '대형평수', '방네개이상', '화장실두개']   103동   강남구청담동         None
# 34267     ['10년이내', '역세권', '방세개', '화장실두개']   103동   강남구청담동         None
#
#           address
# 0      Error: 401
# 1      Error: 401
# 2      Error: 401
# 3      Error: 401
# 4      Error: 401
# ...           ...
# 34253        None
# 34260        None
# 34262        None
# 34264        None
# 34267        None
#
# [6693 rows x 20 columns]

# %%
df.head()
# Out:
#        atclNo     atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc hanPrc  \
# 0  2430161062     중소형사무실      사무실       월세     3/5    3000      210  3,000
# 1  2429217025     중소형사무실      사무실       월세     3/5    3000      210  3,000
# 2  2429335888       일반상가       상가       월세     1/4   10000      450     1억
# 3  2430435227  쌍용더플래티넘잠실     오피스텔       월세    6/16    1000      110  1,000
# 4  2430450003        다가구   단독/다가구       매매    3/B1  340000        0    34억
#
#   spc1    spc2 direction atclCfmYmd        lat         lng  \
# 0  100    89.5        서향  24.06.20.  37.510138  127.085401
# 1   92      92       남동향  24.06.18.  37.510138  127.085401
# 2  119     117        북향  24.06.17.  37.509996  127.085023
# 3   50   27.07        북향  24.06.21.  37.510994  127.084369
# 4  265  615.43        동향  24.06.21.  37.507930  127.083041
#
#                    atclFetrDesc                      tagList bildNm      town
# 0            전용27, 잠실새내역세, 주차2대          [25년이상, 융자금적은, 역세권]         송파구 잠실7동
# 1  실사진O 잠실새내역 2분, 깔끔한 사무실, 전용27             [25년이상, 역세권, 중층]         송파구 잠실7동
# 2     잠실새내역 먹자골목 야장있는 예쁜 호프집무권리             [25년이상, 역세권, 1층]         송파구 잠실7동
# 3          ON I 제일넓은타입 융자없이깔끔한집           [2년이내, 융자금없는, 역세권]   101동  송파구 잠실7동
# 4                   잠실동 초급매 다가구  [25년이내, 급매, 방네개이상, 화장실네개이상]         송파구 잠실7동

# %%
selected_columns = ["atclNo", "atclNm", "rletTpNm","tradTpNm", "flrInfo", "prc","rentPrc","hanPrc","spc1","spc2", "direction", "lat", "lng", "atclFetrDesc", "tagList","bildNm","town"]
df["town"] = keyword
df = df[selected_columns].reset_index(drop=True)

# %%
df.head(1)
# Out:
#        atclNo atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc     hanPrc  \
# 0  2427003676     빌딩       건물       월세    7/B2  134000     9500  13억 4,000
#
#   spc1     spc2 direction        lat         lng               atclFetrDesc  \
# 0  666  2513.61            37.511249  127.113144  MIDAS 신축 건물 통임대 임대조건 협의가능
#
#        tagList bildNm      town
# 0  [2년이내, 역세권]         송파구 잠실4동

# %%
df.to_csv(f'./dataNop/{keyword}_crawling.csv', index=False, encoding='utf-8-sig')

# %%
df
# Out:
#           atclNo            atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0     2427408730                신구     오피스텔       월세   10/13    2000       65
# 1     2427477455  강동역신동아파밀리에(주상복합)      아파트       매매   29/41  130000        0
# 2     2427401843       진넥스빌Ⅲ(주상복합)      아파트       매매    3/15   70000        0
# 3     2427331089    래미안강동팰리스(주상복합)      아파트       매매    3/45  133000        0
# 4     2427354478  강동역신동아파밀리에(주상복합)      아파트       전세    8/41   82000        0
# ...          ...               ...      ...      ...     ...     ...      ...
# 1815  2424009993              일반원룸       원룸       월세    9/15    9000       20
# 1816  2424022895    래미안강동팰리스(주상복합)      아파트       매매    중/45  136000        0
# 1817  2424022263    래미안강동팰리스(주상복합)      아파트       매매    중/45  135000        0
# 1818  2423995897                빌라       빌라       전세     중/6   36000        0
# 1819  2424003611       현일디와이디(도시형)      아파트       월세    중/13   22000       10
#
#          hanPrc spc1    spc2 direction        lat         lng  \
# 0         2,000   54   36.48        서향  37.538545  127.135674
# 1           13억  144  107.34        남향  37.536616  127.133071
# 2            7억   88   75.43        남향  37.536136  127.132805
# 3     13억 3,000  121   84.97       남서향  37.537341  127.132464
# 4      8억 2,000  144  107.34        남향  37.536763  127.133567
# ...         ...  ...     ...       ...        ...         ...
# 1815      9,000   24   15.12       북동향  37.536635  127.136189
# 1816  13억 6,000  121   84.97       남서향  37.537341  127.132464
# 1817  13억 5,000  121   84.97       북서향  37.537341  127.132464
# 1818   3억 6,000   55   49.52        남향  37.531958  127.139537
# 1819   2억 2,000   22   14.84        남향  37.537969  127.133034
#
#                                atclFetrDesc                    tagList bildNm  \
# 0                                  강동역 7분거리    [25년이상, 역세권, 소형평수, 방한개]     1동
# 1          확트인 월드타워뷰. 남향. 강동역바로연결. 편리한생활보장.  [10년이내, 역세권, 대형평수, 방네개이상]  1101동
# 2          특올수리. 베란다. 수납넉넉. 층간소음걱정NO. 강동역바로          [25년이내, 올수리, 역세권]     1동
# 3     사계절 예쁜뷰. 호텔급 커뮤니티시설. 헬스사우나무료 .갭투.보안철저     [10년이내, 역세권, 필로티, 방세개]   103동
# 4               올수리. 풀시스템에어컨. 남향. 강동역 바로연결.    [10년이내, 올수리, 역세권, 대형평수]  1102동
# ...                                     ...                        ...    ...
# 1815        5호선 강동 초역세 강동성심병원 앞 수납공간 많은 풀옵션  [15년이내, 융자금없는, 역세권, 소형평수]
# 1816         월드타워뷰. 편리한교통. 골프.헬스.사우나. 게스트룸.   [10년이내, 역세권, 방세개, 화장실두개]   103동
# 1817               상태최상.트인뷰. 편리한교통. 다양한커뮤니티   [10년이내, 역세권, 방세개, 화장실두개]   103동
# 1818                   내부깨끗 지정주차 지분넓은 안전한전세  [15년이내, 융자금없는, 소형평수, 방세개]
# 1819   강동역도보2분 신축급 풀옵션 투룸,고층,HF버팀목대출,보증보험가능  [10년이내, 융자금없는, 역세권, 소형평수]     1동
#
#           town
# 0     송파구 풍납1동
# 1     송파구 풍납1동
# 2     송파구 풍납1동
# 3     송파구 풍납1동
# 4     송파구 풍납1동
# ...        ...
# 1815  송파구 풍납1동
# 1816  송파구 풍납1동
# 1817  송파구 풍납1동
# 1818  송파구 풍납1동
# 1819  송파구 풍납1동
#
# [1820 rows x 17 columns]

# %%
# Out:
#            atclNo    cortarNo         atclNm atclStatCd rletTpCd uprRletTpCd  \
# 0      2426329376  1168010300   디에이치퍼스티어아이파크         R0      A01         A01
# 1      2426319116  1168010300   디에이치퍼스티어아이파크         R0      A01         A01
# 2      2426330636  1168010300   디에이치퍼스티어아이파크         R0      A01         A01
# 3      2426292674  1168010300       래미안블레스티지         R0      A01         A01
# 4      2426303207  1168010300   디에이치퍼스티어아이파크         R0      A01         A01
# ...           ...         ...            ...        ...      ...         ...
# 24762  2422527668  1168010100     대명벨리온(도시형)         R0      A01         A01
# 24763  2425514914  1168010100    뜨라네(828-76)         R0      A01         A01
# 24764  2422566461  1168010100         중소형사무실         R0      D01         D01
# 24765  2422537172  1168010100            네스빌         R0      A02         A02
# 24766  2425425060  1168010100  역삼EG소울리더(도시형)         R0      A01         A01
#
#       rletTpNm tradTpCd tradTpNm vrfcTpCd  ... dtlAddr  sameAddrPremMin  \
# 0          아파트       B1       전세    NDOC1  ...     NaN              NaN
# 1          아파트       A1       매매    NDOC1  ...     NaN              NaN
# 2          아파트       B1       전세    NDOC1  ...     NaN              NaN
# 3          아파트       B1       전세    OWNER  ...     NaN              NaN
# 4          아파트       B2       월세    NDOC1  ...     NaN              NaN
# ...        ...      ...      ...      ...  ...     ...              ...
# 24762      아파트       B2       월세    OWNER  ...     NaN              NaN
# 24763      아파트       B2       월세      DOC  ...     NaN              NaN
# 24764      사무실       B2       월세    OWNER  ...     NaN              NaN
# 24765     오피스텔       B1       전세    NDOC1  ...     NaN              NaN
# 24766      아파트       A1       매매      DOC  ...     NaN              NaN
#
#        sameAddrPremMax                                          repImgUrl  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN  /20240529_150/land_naver_1716954134244cK1vF_JP...
# 4                  NaN                                                NaN
# ...                ...                                                ...
# 24762              NaN  /20240516_58/land_naver_1715846838107XrkpK_JPE...
# 24763              NaN                                                NaN
# 24764              NaN                                                NaN
# 24765              NaN  /20240508_101/land_naver_1715153902606uqoUF_JP...
# 24766              NaN  /20240524_271/land_naver_17165198326365jqbN_JP...
#
#       repImgTpCd  repImgThumb sameAddrMaxPrc2 sameAddrMinPrc2     town  \
# 0            NaN          NaN             NaN             NaN  강남구 개포동
# 1            NaN          NaN             NaN             NaN  강남구 개포동
# 2            NaN          NaN             NaN             NaN  강남구 개포동
# 3             10      f130_98             NaN             NaN  강남구 개포동
# 4            NaN          NaN             400             500  강남구 개포동
# ...          ...          ...             ...             ...      ...
# 24762         10      f130_98             NaN             NaN  강남구 역삼동
# 24763        NaN          NaN             260             300  강남구 역삼동
# 24764        NaN          NaN             NaN             NaN  강남구 역삼동
# 24765         10      f130_98             NaN             NaN  강남구 역삼동
# 24766         10      f130_98             NaN             NaN  강남구 역삼동
#
#        sellrNm
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 24762      NaN
# 24763      NaN
# 24764      NaN
# 24765      NaN
# 24766      NaN
#
# [24767 rows x 52 columns]

# %%
df['id'] = range(1, len(df) + 1)

# %%
apartment_df = df[df['rletTpNm'] == '아파트']
officetel_df = df[df['rletTpNm'] == '오피스텔']

# %%
apartment_df
# Out:
#            atclNo         atclNm tradTpNm flrInfo     prc  rentPrc     hanPrc  \
# 0      2426329376   디에이치퍼스티어아이파크       전세   11/32  320000        0        32억
# 1      2426319116   디에이치퍼스티어아이파크       매매   21/26  430000        0        43억
# 2      2426330636   디에이치퍼스티어아이파크       전세   12/35  250000        0        25억
# 3      2426292674       래미안블레스티지       전세     4/8  105000        0  10억 5,000
# 4      2426303207   디에이치퍼스티어아이파크       월세   22/33  100000      600        10억
# ...           ...            ...      ...     ...     ...      ...        ...
# 24759  2423623584  강남서해그랑블(주상복합)       월세    중/10   40000       80         4억
# 24761  2425505199          금호어울림       월세    중/15   40000      300         4억
# 24762  2422527668     대명벨리온(도시형)       월세     3/7    1000       95      1,000
# 24763  2425514914    뜨라네(828-76)       월세     저/6   10000      260         1억
# 24766  2425425060  역삼EG소울리더(도시형)       매매     고/9   20000        0         2억
#
#       spc1    spc2 direction        lat         lng  \
# 0      220  171.65       남서향  37.481919  127.057858
# 1      144  112.85       남서향  37.478823  127.058843
# 2      169  132.81       남동향  37.480453  127.058339
# 3       80   59.88       남서향  37.480127  127.063991
# 4      201  156.96        남향  37.481182  127.057478
# ...    ...     ...       ...        ...         ...
# 24759   94   70.57       남서향  37.493134  127.039216
# 24761  155  133.77        남향  37.492233  127.034715
# 24762   27   17.68       북서향  37.497964  127.039165
# 24763   97   84.42        동향  37.497454  127.033053
# 24766   22   14.69        동향  37.497152  127.033589
#
#                               atclFetrDesc  \
# 0      66 O로얄동로얄층O조중석식O최대규모커뮤니티O근린공원O구룡역근접
# 1      44 뷰가 확 트여야 가치가  더 높습니다 입주가능한 매매 물건
# 2              51O뷰좋은집O커뮤니티바로연결O근린공원O생활편리동
# 3          24  V풀옵션 V장기거주 V호텔식 조중식 V수영장사우나
# 4                61O시그니처동O커뮤니티연결동O근린공원O뷰좋음
# ...                                    ...
# 24759    공동불가 입점업소 2룸2욕실 뷰 컨디션 좋은호실 빠른계약예상
# 24761       채광좋은남향 넓은평수 내부깨끗 주차편리 입주협의가능해요
# 24762                   BEST역삼역도보10분이내,보안굿
# 24763          쓰리룸 리모델링호실 빠른입주가능 내부깨끗 주차편리
# 24766                  강남역세권 전세낀 매매, 깔끔 매물
#
#                                    tagList bildNm     town   area    id
# 0         ['2년이내', '대단지', '대형평수', '방네개이상']   104동  강남구 개포동      1     1
# 1         ['2년이내', '대단지', '대형평수', '방네개이상']   146동  강남구 개포동      2     2
# 2         ['2년이내', '대단지', '대형평수', '방네개이상']   101동  강남구 개포동      3     3
# 3                ['10년이내', '융자금적은', '대단지']   223동  강남구 개포동      4     4
# 4         ['2년이내', '대단지', '대형평수', '방네개이상']   103동  강남구 개포동      5     5
# ...                                    ...    ...      ...    ...   ...
# 24759            ['15년이내', '방두개', '화장실두개']     1동  강남구 역삼동  24760  5760
# 24761  ['25년이내', '융자금없는', '대형평수', '방네개이상']   101동  강남구 역삼동  24762  5761
# 24762             ['15년이내', '역세권', '소형평수']     1동  강남구 역삼동  24763  5762
# 24763   ['25년이내', '융자금없는', '방세개', '화장실두개']     A동  강남구 역삼동  24764  5763
# 24766             ['15년이내', '역세권', '소형평수']     1동  강남구 역삼동  24767  5764
#
# [5764 rows x 18 columns]

# %%
officetel_df.to_csv('GangnamOfficetel.csv', index=False, encoding='utf-8-sig')

# %%
filtered_df = df[~df['rletTpNm'].isin(['아파트', '오피스텔'])]

# %%
dfforadd = df

# %%
selected_columns = ["lat", "lng", "area"]
dfforadd = dfforadd[selected_columns]

# %%
df = df.drop(columns=['town'])

# %%
df.to_csv('GangnamApartment.csv', index=False, encoding='utf-8-sig')

# %%
df.isnull().sum()
# Out:
# id              0
# area            0
# atclNo          0
# atclNm          0
# rletTpNm        0
# tradTpNm        0
# flrInfo         0
# prc             0
# rentPrc         0
# hanPrc          0
# spc1            0
# spc2            0
# direction       0
# atclFetrDesc    0
# tagList         0
# bildNm          0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.to_csv(f'GangnamALL.csv', index=False, encoding='utf-8-sig')

# %%
df.info() # 데이터프레임의 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   atclNo    100 non-null    int64
#  1   atclNm    100 non-null    object
#  2   rletTpNm  100 non-null    object
#  3   prc       100 non-null    int64
#  4   lat       100 non-null    float64
#  5   lng       100 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB

# %%
df.isnull().sum() # 데이터프레임의 결측치 정보 출력
# Out:
# atclNo      0
# atclNm      0
# rletTpNm    0
# prc         0
# lat         0
# lng         0
# dtype: int64

# %%
df = pd.read_csv('양천구_신월동_100.csv',encoding='utf-8')
df
# Out:
#         atclNo       atclNm rletTpNm     prc        lat         lng
# 0   2426130767  목동센트럴아이파크위브      아파트   60000  37.517669  126.844850
# 1   2425438083         상가주택     상가주택  250000  37.517523  126.842308
# 2   2423609940        스카이캐슬      아파트   97000  37.520542  126.844645
# 3   2425722784           단독   단독/다가구   15000  37.518080  126.842841
# 4   2422558122         일반상가       상가  108000  37.517721  126.842002
# ..         ...          ...      ...     ...        ...         ...
# 95  2423233490           빌라       빌라   25500  37.521391  126.844122
# 96  2426060226     신성미소지움3차      아파트   63000  37.522890  126.841696
# 97  2425566480           금용      아파트   83000  37.520768  126.842091
# 98  2426059502    신정뉴타운롯데캐슬      아파트   81000  37.518923  126.847877
# 99  2425011452  목동센트럴아이파크위브      아파트   60000  37.516503  126.845958
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 데이터 밸런스 맞추기

# %%
df = pd.read_csv('GangnamAdd.csv',encoding='utf-8')
df1 = pd.read_csv('GangnamALL.csv',encoding='utf-8')

# %%
df
# Out:
#         area        lat         lng          road_address            address
# 0          1  37.481919  127.057858     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 1          2  37.478823  127.058843     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 2          3  37.480453  127.058339     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 3          4  37.480127  127.063991       서울특별시 강남구 선릉로 8    서울 강남구 개포동 1280
# 4          5  37.481182  127.057478     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# ...      ...        ...         ...                   ...                ...
# 24762  24763  37.497964  127.039165   서울특별시 강남구 역삼로25길 27   서울 강남구 역삼동 727-2
# 24763  24764  37.497454  127.033053     서울특별시 강남구 개포로 310  서울 강남구 역삼동 828-76
# 24764  24765  37.493709  127.038101   서울특별시 강남구 논현로67길 23   서울 강남구 역삼동 795-2
# 24765  24766  37.495225  127.032596    서울특별시 강남구 역삼로7길 17  서울 강남구 역삼동 830-41
# 24766  24767  37.497152  127.033589  서울특별시 강남구 테헤란로14길 34  서울 강남구 역삼동 828-28
#
# [24767 rows x 5 columns]

# %%
df = df1.sample(frac=1).reset_index(drop=True)
df
# Out:
#           id   area      atclNo        atclNm rletTpNm tradTpNm flrInfo  \
# 0      20374  20374  2423542341         대형사무실      사무실       월세     1/5
# 1      20938  20938  2425941602            빌라       빌라       매매     2/2
# 2      11749  11749  2425945043        중소형사무실      사무실       월세    B1/5
# 3      17651  17651  2424576763          푸른마을      아파트       전세    3/15
# 4      16198  16198  2422550993          미성2차      아파트       매매   14/17
# ...      ...    ...         ...           ...      ...      ...     ...
# 24762  14031  14031  2422035727            기타       원룸       월세     중/3
# 24763    304    304  2424823564  디에이치퍼스티어아이파크      아파트       월세    8/21
# 24764  20152  20152  2424016436        청담아이파크      아파트       월세    중/19
# 24765   1023   1023  2426280490  디에이치퍼스티어아이파크      아파트       월세    중/26
# 24766  20132  20132  2424880186        중소형사무실      사무실       월세    8/15
#
#           prc  rentPrc    hanPrc spc1    spc2 direction  \
# 0       25000     2300  2억 5,000  561  561.31       남서향
# 1       85000        0  8억 5,000   48   44.28        남향
# 2        2000      160     2,000   89   89.00        남향
# 3       75000        0  7억 5,000  103   84.93        남향
# 4      300000        0       30억   95   74.40        동향
# ...       ...      ...       ...  ...     ...       ...
# 24762    1000       90     1,000   30   30.00        동향
# 24763   30000      420        3억  110   84.82       남동향
# 24764  120000      330       12억  137  110.13        동향
# 24765   60000      300        6억  110   84.82        남향
# 24766    8000      400     8,000  171  171.00        북향
#
#                                    atclFetrDesc  \
# 0                                             0
# 1                                             0
# 2                                       스튜디오 추천
# 3                          주인직매물,조용일조권좋은남향,권리깨끗
# 4                     실매물  투자가치 유망한곳으로 매수적기 입니다
# ...                                         ...
# 24762                     신사역 가로수길 주차 가능한 원룸 월세
# 24763            33A 생활인프라 모두 근접한  로얄세대 보증금조정가능
# 24764               내부 에이급 리모델링  최상 한강뷰 멋진집입니다.
# 24765              33  전망좋은 동  학세권  최고 커뮤니티  신축
# 24766  실사진0 특 A급 인테리어 영동대교 남단 대로변 세련된 사무실 강력 추천
#
#                                       tagList bildNm
# 0            ['10년이내', '1층', '주차가능', '천장에어컨']      0
# 1                    ['25년이상', '역세권', '소형평수']      0
# 2      ['25년이내', '융자금없는', '지하층', '관리비10만원이하']      0
# 3            ['25년이상', '역세권', '방세개', '화장실두개']   102동
# 4             ['25년이상', '방세개', '화장실한개', '고층']    28동
# ...                                       ...    ...
# 24762                ['25년이상', '소형평수', '방한개']      0
# 24763         ['2년이내', '융자금없는', '역세권', '대단지']   113동
# 24764     ['15년이내', '대형평수', '방네개이상', '화장실두개']     1동
# 24765         ['2년이내', '대단지', '방세개', '화장실두개']   159동
# 24766        ['25년이내', '중층', '주차가능', '엘리베이터']      0
#
# [24767 rows x 16 columns]

# %%
df.to_csv('GangnamALL.csv', index=False, encoding='utf-8-sig')

# %%
df

# %%
df
# Out:
#         area        lat         lng          road_address            address
# 0          1  37.481919  127.057858     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 1          2  37.478823  127.058843     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 2          3  37.480453  127.058339     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 3          4  37.480127  127.063991       서울특별시 강남구 선릉로 8    서울 강남구 개포동 1280
# 4          5  37.481182  127.057478     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# ...      ...        ...         ...                   ...                ...
# 24762  24763  37.497964  127.039165   서울특별시 강남구 역삼로25길 27   서울 강남구 역삼동 727-2
# 24763  24764  37.497454  127.033053     서울특별시 강남구 개포로 310  서울 강남구 역삼동 828-76
# 24764  24765  37.493709  127.038101   서울특별시 강남구 논현로67길 23   서울 강남구 역삼동 795-2
# 24765  24766  37.495225  127.032596    서울특별시 강남구 역삼로7길 17  서울 강남구 역삼동 830-41
# 24766  24767  37.497152  127.033589  서울특별시 강남구 테헤란로14길 34  서울 강남구 역삼동 828-28
#
# [24767 rows x 5 columns]

# %%
df1
# Out:
#           id   area      atclNo         atclNm rletTpNm tradTpNm flrInfo  \
# 0          1      1  2426329376   디에이치퍼스티어아이파크      아파트       전세   11/32
# 1          2      2  2426319116   디에이치퍼스티어아이파크      아파트       매매   21/26
# 2          3      3  2426330636   디에이치퍼스티어아이파크      아파트       전세   12/35
# 3          4      4  2426292674       래미안블레스티지      아파트       전세     4/8
# 4          5      5  2426303207   디에이치퍼스티어아이파크      아파트       월세   22/33
# ...      ...    ...         ...            ...      ...      ...     ...
# 24762  24763  24763  2422527668     대명벨리온(도시형)      아파트       월세     3/7
# 24763  24764  24764  2425514914    뜨라네(828-76)      아파트       월세     저/6
# 24764  24765  24765  2422566461         중소형사무실      사무실       월세     2/6
# 24765  24766  24766  2422537172            네스빌     오피스텔       전세     2/9
# 24766  24767  24767  2425425060  역삼EG소울리더(도시형)      아파트       매매     고/9
#
#           prc  rentPrc     hanPrc spc1    spc2 direction  \
# 0      320000        0        32억  220  171.65       남서향
# 1      430000        0        43억  144  112.85       남서향
# 2      250000        0        25억  169  132.81       남동향
# 3      105000        0  10억 5,000   80   59.88       남서향
# 4      100000      600        10억  201  156.96        남향
# ...       ...      ...        ...  ...     ...       ...
# 24762    1000       95      1,000   27   17.68       북서향
# 24763   10000      260         1억   97   84.42        동향
# 24764    2000      200      2,000  129  129.60       남서향
# 24765   19000        0   1억 9,000   44   23.68       남동향
# 24766   20000        0         2억   22   14.69        동향
#
#                               atclFetrDesc  \
# 0      66 O로얄동로얄층O조중석식O최대규모커뮤니티O근린공원O구룡역근접
# 1      44 뷰가 확 트여야 가치가  더 높습니다 입주가능한 매매 물건
# 2              51O뷰좋은집O커뮤니티바로연결O근린공원O생활편리동
# 3          24  V풀옵션 V장기거주 V호텔식 조중식 V수영장사우나
# 4                61O시그니처동O커뮤니티연결동O근린공원O뷰좋음
# ...                                    ...
# 24762                   BEST역삼역도보10분이내,보안굿
# 24763          쓰리룸 리모델링호실 빠른입주가능 내부깨끗 주차편리
# 24764            사진O 층전체사용 주차가능 가성비 좋은 사무실
# 24765         실물 더 넓은 테라스 굿 시세대비 저렴 빠른계약예상
# 24766                  강남역세권 전세낀 매매, 깔끔 매물
#
#                                            tagList bildNm
# 0                 ['2년이내', '대단지', '대형평수', '방네개이상']   104동
# 1                 ['2년이내', '대단지', '대형평수', '방네개이상']   146동
# 2                 ['2년이내', '대단지', '대형평수', '방네개이상']   101동
# 3                        ['10년이내', '융자금적은', '대단지']   223동
# 4                 ['2년이내', '대단지', '대형평수', '방네개이상']   103동
# ...                                            ...    ...
# 24762                     ['15년이내', '역세권', '소형평수']     1동
# 24763           ['25년이내', '융자금없는', '방세개', '화장실두개']     A동
# 24764  ['25년이상', '지상층(1층제외)', '관리비10만원이하', '주차가능']      0
# 24765                      ['25년이내', '테라스', '역세권']     1동
# 24766                     ['15년이내', '역세권', '소형평수']     1동
#
# [24767 rows x 16 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#         area        lat         lng          road_address            address  \
# 0      23791  37.497110  127.037435   서울특별시 강남구 역삼로19길 29  서울 강남구 역삼동 745-12
# 1      22531  37.485625  127.035919  서울특별시 강남구 강남대로42길 23  서울 강남구 도곡동 954-18
# 2      17726  37.481545  127.078599    서울특별시 강남구 광평로10길 6     서울 강남구 일원동 731
# 3        893  37.479332  127.058767     서울특별시 강남구 개포로 310   서울 강남구 개포동 660-1
# 4      17234  37.490251  127.082356  서울특별시 강남구 양재대로31길 13   서울 강남구 일원동 686-3
# ...      ...        ...         ...                   ...                ...
# 24762  23969  37.494933  127.035423     서울특별시 강남구 역삼로 149   서울 강남구 역삼동 751-7
# 24763  22567  37.491811  127.040029     서울특별시 강남구 도곡로 188   서울 강남구 도곡동 544-2
# 24764  24238  37.498924  127.033882   서울특별시 강남구 테헤란로16길 9  서울 강남구 역삼동 735-29
# 24765  14223  37.519372  127.019631   서울특별시 강남구 도산대로1길 40  서울 강남구 신사동 507-11
# 24766   9379  37.511212  127.053898     서울특별시 강남구 삼성로 557   서울 강남구 삼성동 120-7
#
#           id      atclNo        atclNm rletTpNm tradTpNm flrInfo     prc  \
# 0      23791  2425751350          일반상가       상가       월세     1/5    1000
# 1      22531  2420975917          일반상가       상가       월세     1/6   11000
# 2      17726  2421964775          한솔마을      아파트       매매     4/5  230000
# 3        893  2426321631  디에이치퍼스티어아이파크      아파트       월세    중/35   90000
# 4      17234  2421849895            단독   단독/다가구       월세    B1/2    2000
# ...      ...         ...           ...      ...      ...     ...     ...
# 24762  23969  2423595052        중소형사무실      사무실       월세     1/5   23000
# 24763  22567  2420911223          일반상가       상가       월세     3/4    5000
# 24764  24238  2425134432        중소형사무실      사무실       월세     1/5    4000
# 24765  14223  2421547169         대형사무실      사무실       월세     3/6    4000
# 24766   9379  2425102396          일반상가       상가       월세    B2/7    1000
#
#        rentPrc    hanPrc spc1    spc2 direction  \
# 0          220     1,000   76   76.00        동향
# 1          980  1억 1,000  250  132.00        남향
# 2            0       23억  110   84.73        남향
# 3          540        9억  169  132.81       남동향
# 4           60     2,000   40   40.00       남동향
# ...        ...       ...  ...     ...       ...
# 24762     2300  2억 3,000  732  732.20        남향
# 24763      300     5,000  198  181.80       북서향
# 24764      600     4,000  133  133.80        서향
# 24765      400     4,000  200  160.00        서향
# 24766      100     1,000  274  274.40        동향
#
#                                  atclFetrDesc  \
# 0                       좋은 매물만 엑기스로 추려드리겠습니다.
# 1                      원하시는 매장 반드시 찾아 드리겠습니다.
# 2                  확장 샤시교체 특올수리 입주가능 강력추천드립니다
# 3                                           0
# 4          2룸 단독주택 반지하 월세, 보증금 조절 가능, 미닫이문 있음
# ...                                       ...
# 24762                 대로변 소형빌딩 임대 현병원운영중 원복협의
# 24763  강남BEST 도곡로대로변,가시성,노출도 좋은상가,시세대비 저렴한 월세
# 24764      실사진O 역삼역  S급 컨디션 인테리어 손 볼 곳 없는 사무실
# 24765         D실사진. 더블역세권 인테리어 냉난방기 완비. 자주식주차
# 24766           무권리, 삼성중앙역 3분, 초역세권, 지하 2층 임대
#
#                                    tagList bildNm
# 0      ['25년이상', '역세권', '1층', '관리비20만원이하']      0
# 1           ['2년이내', '융자금없는', '역세권', '1층']      0
# 2         ['25년이상', '올수리', '방세개', '화장실두개']   303동
# 3         ['2년이내', '대단지', '대형평수', '방네개이상']   173동
# 4        ['25년이상', '융자금없는', '소형평수', '방두개']      0
# ...                                    ...    ...
# 24762     ['25년이상', '1층', '주차가능', '엘리베이터']      0
# 24763       ['25년이상', '고층', '주차가능', '총4층']      0
# 24764       ['25년이상', '역세권', '1층', '주차가능']      0
# 24765       ['25년이상', '역세권', '중층', '주차가능']      0
# 24766      ['25년이상', '역세권', '지하층', '주차가능']      0
#
# [24767 rows x 20 columns]

# %%
merged_df = pd.merge(df, df1, on='area')

# %%
rletTpNm_distribution = merged_df['rletTpNm'].value_counts()

# %%
rletTpNm_distribution = df1['rletTpNm'].value_counts()

# %%
rletTpNm_distribution
# Out:
# rletTpNm
# 사무실        6911
# 아파트        5764
# 상가         4919
# 빌라         2138
# 건물         1372
# 단독/다가구     1272
# 오피스텔        925
# 재건축         855
# 원룸          412
# 상가주택        124
# 토지           52
# 오피스텔분양권      13
# 아파트분양권        8
# 공장/창고         2
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv('./dataNop/apartment.csv', encoding='utf-8')
df2 = pd.read_csv('./dataNop/officetel.csv', encoding='utf-8')

# %%
df.head()
# Out:
#        atclNo        atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0  2430493738  디에이치퍼스티어아이파크      아파트       전세    8/26  175000        0
# 1  2430483040  디에이치퍼스티어아이파크      아파트       월세   17/35   50000      440
# 2  2430483852  디에이치퍼스티어아이파크      아파트       전세   22/33  290000        0
# 3  2430476863  디에이치퍼스티어아이파크      아파트       전세   16/18   68000        0
# 4  2430461819  디에이치퍼스티어아이파크      아파트       월세   30/33  100000      600
#
#       hanPrc  spc1    spc2  ...           atclCfmYmd        lat         lng  \
# 0  17억 5,000   144  112.85  ...  2024-06-21T00:00:00  37.482462  127.056707
# 1         5억   125   96.82  ...  2024-06-21T00:00:00  37.479760  127.058636
# 2        29억   201  156.96  ...  2024-06-21T00:00:00  37.481182  127.057478
# 3   6억 8,000    50   34.99  ...  2024-06-21T00:00:00  37.478622  127.056892
# 4        10억   201  156.96  ...  2024-06-21T00:00:00  37.481182  127.057478
#
#                              atclFetrDesc                            tagList  \
# 0  44 1획지 주인직접 초역세권 식세 초중품아 채광.전망굿 고급커뮤니티   ['2년이내', '대단지', '대형평수', '방네개이상']
# 1   38. 커뮤니티 최상. 조중석식.풀에,이태리산 아트월, 식세기 옵션  ['2년이내', '융자금없는', '대단지', '방네개이상']
# 2  61.대형 평형 다량보유.중앙공원뷰.이태리아트월,붙박이장,오븐,식세기   ['2년이내', '융자금없는', '대단지', '대형평수']
# 3             15 주인의뢰,귀한소형, 탁트인뷰, 럭셔리커뮤니티     ['2년이내', '대단지', '소형평수', '방한개']
# 4                   61 빠른입주,보증금10억에서 부터가능   ['2년이내', '융자금없는', '대단지', '대형평수']
#
#   bildNm     town road_address     address           image
# 0   118동  강남구개포1동          NaN  Error: 401  apartment.jpeg
# 1   174동  강남구개포1동          NaN  Error: 401  apartment.jpeg
# 2   103동  강남구개포1동          NaN  Error: 401  apartment.jpeg
# 3   140동  강남구개포1동          NaN  Error: 401  apartment.jpeg
# 4   103동  강남구개포1동          NaN  Error: 401  apartment.jpeg
#
# [5 rows x 21 columns]

# %%
import ast

# tagList 열의 각 문자열을 리스트로 변환
df['tagList'] = df['tagList'].apply(ast.literal_eval)

# tagList 열의 값을 모두 풀어 하나의 리스트로 만듦
all_tags = [tag for sublist in df['tagList'] for tag in sublist]

# 고유한 태그를 추출하여 리스트로 변환
unique_tags = list(set(all_tags))

# 결과 출력
print(unique_tags)
# Out:
# ['4년이내', '탑층', '필로티', '세대당1대', '급매', '세대분리', '대형평수', '대단지', '확장형', '방두개', '역세권', '융자금적은', '중층', '올수리', '복층', '화장실세개', '마당', '테라스', '주차가능', '세대당 1.5대이상', '융자금없는', '2년이내', '관리비20만원이하', '화장실네개이상', '15년이내', '방네개이상', '25년이내', '1층', '소형평수', '저층', '10년이내', '주방교체', '욕실수리', '방한개', '화장실한개', '고층', '방세개', '25년이상', '화장실두개']

# %%
df2['image'] = df2['rletTpNm'].apply(lambda x: 'apartment.jpeg' if x == '아파트' else 'officetel.jpeg')

# %%
df2
# Out:
#           atclNo     atclNm rletTpNm tradTpNm flrInfo     prc  rentPrc  \
# 0     2429962181        렉스힐     오피스텔       매매     2/7   41000        0
# 1     2429962181        렉스힐     오피스텔       매매     2/7   41000        0
# 2     2430511404  강남역서희스타힐스     오피스텔       매매    9/12   27000        0
# 3     2430373834   강남웅진베어스빌     오피스텔       월세    6/16   10000      110
# 4     2430327129   강남웅진베어스빌     오피스텔       전세    6/16   32000        0
# ...          ...        ...      ...      ...     ...     ...      ...
# 1559  2427092490        리버뷰     오피스텔       월세   14/15    1000       80
# 1560  2429060192     더오키드청담     오피스텔       월세   13/17   20000      700
# 1561  2428816002     더오키드청담     오피스텔       매매    6/17  245000        0
# 1562  2426348898        리버뷰     오피스텔       월세   14/15    1000      100
# 1563  2428555677     더오키드청담     오피스텔       월세    9/17   10000      550
#
#          hanPrc  spc1   spc2  ...           atclCfmYmd        lat         lng  \
# 0      4억 1,000    45  29.25  ...  2024-06-18T00:00:00  37.483014  127.062559
# 1      4억 1,000    45  29.25  ...  2024-06-18T00:00:00  37.483014  127.062559
# 2      2억 7,000    65  29.88  ...  2024-06-21T00:00:00  37.491413  127.032589
# 3            1억    48  26.26  ...  2024-06-20T00:00:00  37.490213  127.032788
# 4      3억 2,000    48  26.26  ...  2024-06-20T00:00:00  37.490213  127.032788
# ...         ...   ...    ...  ...                  ...        ...         ...
# 1559      1,000    52  30.36  ...  2024-06-03T00:00:00  37.522278  127.055325
# 1560         2억    94  69.17  ...  2024-06-13T00:00:00  37.522677  127.055081
# 1561  24억 5,000    94  69.17  ...  2024-06-12T00:00:00  37.522677  127.055081
# 1562      1,000    68  39.16  ...  2024-05-29T00:00:00  37.522278  127.055325
# 1563         1억    76  56.05  ...  2024-06-11T00:00:00  37.522677  127.055081
#
#                                atclFetrDesc  \
# 0                    임대안고 매매 구룹과외등 공부방으로 최적
# 1                    임대안고 매매 구룹과외등 공부방으로 최적
# 2                                       NaN
# 3                        전입대출,보증보험가능,층고높은복층
# 4                        전입대출,보증보험가능,층고높은복층
# ...                                     ...
# 1559                초역세권 청담공원전망 개별냉난방 업무시설
# 1560  소유주직접의뢰  한강뷰 공원뷰 청담역초역세권 건조기 스타일러 식세기
# 1561               청담역 영동대교 남단 신축 하이엔드 오피스텔
# 1562                           대로변 업무용 오피스텔
# 1563                청담동 투룸 하이엔드 오피스텔 더오키드청담
#
#                                  tagList bildNm     town road_address  \
# 0        ['15년이내', '필로티', '소형평수', '방한개']     1동  강남구개포1동          NaN
# 1        ['15년이내', '필로티', '소형평수', '방한개']     1동  강남구개포2동          NaN
# 2        ['15년이내', '화장실한개', '방한개', '고층']     1동  강남구개포4동          NaN
# 3                ['10년이내', '복층', '소형평수']     1동  강남구개포4동          NaN
# 4                ['10년이내', '복층', '소형평수']     1동  강남구개포4동          NaN
# ...                                  ...    ...      ...          ...
# 1559  ['25년이상', '융자금없는', '역세권', '화장실한개']     1동   강남구청담동          NaN
# 1560              ['2년이내', '역세권', '방한개']     1동   강남구청담동          NaN
# 1561              ['2년이내', '역세권', '방두개']     1동   강남구청담동          NaN
# 1562    ['25년이상', '융자금없는', '역세권', '방한개']     1동   강남구청담동          NaN
# 1563              ['2년이내', '역세권', '방한개']     1동   강남구청담동          NaN
#
#       address           image
# 0         NaN  officetel.jpeg
# 1         NaN  officetel.jpeg
# 2         NaN  officetel.jpeg
# 3         NaN  officetel.jpeg
# 4         NaN  officetel.jpeg
# ...       ...             ...
# 1559      NaN  officetel.jpeg
# 1560      NaN  officetel.jpeg
# 1561      NaN  officetel.jpeg
# 1562      NaN  officetel.jpeg
# 1563      NaN  officetel.jpeg
#
# [1564 rows x 21 columns]

# %%
df.to_csv('./dataNop/apartment.csv', index=False, encoding='utf-8-sig')

# %%
df2.to_csv('./dataNop/officetel.csv', index=False, encoding='utf-8-sig')
